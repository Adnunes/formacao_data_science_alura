# %% [markdown]
# # Relatório de Análise III
#
# ## 1. Imóveis Residenciais

# %%
import pandas as pd

dados = pd.read_csv('/data/workspace_files/aluguel.csv', sep =';')
dados.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tipo</th>
#       <th>Bairro</th>
#       <th>Quartos</th>
#       <th>Vagas</th>
#       <th>Suites</th>
#       <th>Area</th>
#       <th>Valor</th>
#       <th>Condominio</th>
#       <th>IPTU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Quitinete</td>
#       <td>Copacabana</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>40</td>
#       <td>1700.0</td>
#       <td>500.0</td>
#       <td>60.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Casa</td>
#       <td>Jardim Botânico</td>
#       <td>2</td>
#       <td>0</td>
# ...

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
residencial = ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']
residencial
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
selecao = dados['Tipo'].isin(residencial)
selecao
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
dados_residencial = dados[selecao]
dados_residencial
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tipo</th>
#       <th>Bairro</th>
#       <th>Quartos</th>
#       <th>Vagas</th>
#       <th>Suites</th>
#       <th>Area</th>
#       <th>Valor</th>
#       <th>Condominio</th>
#       <th>IPTU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Quitinete</td>
#       <td>Copacabana</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>40</td>
#       <td>1700.0</td>
#       <td>500.0</td>
#       <td>60.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Casa</td>
#       <td>Jardim Botânico</td>
#       <td>2</td>
#       <td>0</td>
# ...

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados_residencial.shape[0]
# Out:
# 22580

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados_residencial.index = range(dados_residencial.shape[0])
dados_residencial
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tipo</th>
#       <th>Bairro</th>
#       <th>Quartos</th>
#       <th>Vagas</th>
#       <th>Suites</th>
#       <th>Area</th>
#       <th>Valor</th>
#       <th>Condominio</th>
#       <th>IPTU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Quitinete</td>
#       <td>Copacabana</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>40</td>
#       <td>1700.0</td>
#       <td>500.0</td>
#       <td>60.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Casa</td>
#       <td>Jardim Botânico</td>
#       <td>2</td>
#       <td>0</td>
# ...

# %% [markdown]
# ## Exportando Base de Dados

# %%
dados_residencial.to_csv('/data/workspace_files/aluguel_residencial.csv', sep=';', index= False)

# %%
dados_residencial_1 = pd.read_csv('/data/workspace_files/aluguel_residencial.csv', sep=';')
dados_residencial_1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tipo</th>
#       <th>Bairro</th>
#       <th>Quartos</th>
#       <th>Vagas</th>
#       <th>Suites</th>
#       <th>Area</th>
#       <th>Valor</th>
#       <th>Condominio</th>
#       <th>IPTU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Quitinete</td>
#       <td>Copacabana</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>40</td>
#       <td>1700.0</td>
#       <td>500.0</td>
#       <td>60.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Casa</td>
#       <td>Jardim Botânico</td>
#       <td>2</td>
#       <td>0</td>
# ...

# %% [markdown]
# # Exercícios:

# %%
import pandas as pd

numeros = [i for i in range(11)]
letras = [chr(i + 65) for i in range(11)]
nome_coluna = ['N']

df = pd.DataFrame(data = numeros, index = letras, columns = nome_coluna)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>E</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>F</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>G</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>H</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>I</th>
#       <td>8</td>
#     </tr>
#     <tr>
# ...

# %%
selecao = df['N'].isin([i for i in range(11) if i % 2 == 0])
df = df[selecao]
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>E</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>G</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>I</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>K</th>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sort_index()
df.sort_index(axis = 1)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>E</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>G</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>I</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>K</th>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import pandas as pd

# %%
data =[[9,6,3], [8,5,2], [7,4,1]]
data
# Out:
# [[9, 6, 3], [8, 5, 2], [7, 4, 1]]

# %%
list('321')
# Out:
# ['3', '2', '1']

# %%
df = pd.DataFrame(data, index= list('ZYX'), columns=list('CBA'))
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>B</th>
#       <th>A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Z</th>
#       <td>9</td>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>8</td>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>X</th>
#       <td>7</td>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sort_index()
df.sort_index(axis = 1)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>B</th>
#       <th>A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Z</th>
#       <td>9</td>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>8</td>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>X</th>
#       <td>7</td>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sort_index(inplace = True, axis = 1)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Z</th>
#       <td>3</td>
#       <td>6</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>2</td>
#       <td>5</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>X</th>
#       <td>1</td>
#       <td>4</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sort_values(by= 'X', inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
#     at line 5294 in sort_values
#     at line 1563 in _get_label_or_level_values
# KeyError: 'X'

# %%
df.sort_values(by= '3', axis =1, inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
#     at line 5294 in sort_values
#     at line 1563 in _get_label_or_level_values
# KeyError: '3'

# %%
data=[[1,2,3],[5, 6, 7]]

df = pd.DataFrame(data=data)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1 = df.sort_index(axis = 0)
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# </div>
